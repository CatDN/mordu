# %% [markdown]
# # Cubic equations of state

# %% [markdown]
# ## Creating the equation of state from already defined objects of mordu

# %%
import mordu 


# select the prebuilt EOS
eos = mordu.storeroom.eos_purefluid.NH3_PR

#
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 5
#       1 import mordu
#       4 # select the prebuilt EOS
# ----> 5 eos = mordu.storeroom.eos_purefluid.NH3_PR
#       7 #
#
# AttributeError: module 'mordu.storeroom' has no attribute 'eos_purefluid'
