# %% [markdown]
# # Cubic equations of state

# %%
import mordu 

# select the fluid
fluid = mordu.fluids.NH3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       1 import mordu
#       3 # select the fluid
# ----> 4 fluid = mordu.fluids.NH3
#
# AttributeError: module 'mordu' has no attribute 'fluids'
