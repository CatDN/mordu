# %% [markdown]
# # Cubic equations of state

# %% [markdown]
# ## Creating the equation of state from already defined objects of mordu

# %%
import mordu 



# import specific fluid
# fluid = mordu.fluids.NH3

# select the prebuilt EOS (Peng Robinson for ammonia)
# eos = mordu.eos_purefluid.NH3_PR

# # print the pressure expression
# print("Pressure expression (sympy expression):")
# print(eos.pressure)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import mordu
#       5 # import specific fluid
#       6 # fluid = mordu.fluids.NH3
#       7
#    (...)     12 # print("Pressure expression (sympy expression):")
#      13 # print(eos.pressure)
#
# File c:\Users\catar\AppData\Local\Programs\Python\Python313\Lib\site-packages\mordu\__init__.py:6
#       4 from .storeroom import cp0s
#       5 from .storeroom import alpha_r_func
# ----> 6 from .storeroom import eos_purefluid
#       9 from .symbols import *
#
# File c:\Users\catar\AppData\Local\Programs\Python\Python313\Lib\site-packages\mordu\storeroom\eos_purefluid.py:12
#      10 # objects
#      11 from .fluids import NH3, H2
# ---> 12 from .cp0s import NH3_cp0_NIST, H2_cp0_NIST
#      13 from .alpha_r_func import alpha_r_0290, alpha_r_0298, alpha_r_0300, alpha_r_0313
#      15 # algorithms and other functions and variables
#
# ImportError: cannot import name 'NH3_cp0_NIST' from 'mordu.storeroom.cp0s' (c:\Users\catar\AppData\Local\Programs\Python\Python313\Lib\site-packages\mordu\storeroom\cp0s.py)

# %% [markdown]
# ### Calculate pressure at specific temperature and density

# %%
# calculate pressure from temperature and density
temperature = 300   # in Kelvin
density = 42.86     # in mol/m3

# convert the pressure expression into a function
pressure_func = sp.lambdify((rho, T), eos.pressure)

# calculate pressure at defined density and temperature
pressure = pressure_func(density, temperature)  # in Pa

print(f"""Pressure at temperature of {temperature} K and density of {density} mol/m3:
    pressure = {pressure} Pa
    pressure = {pressure/1e5} bar""")
# Out:
# Pressure at temperature of 300 K and density of 42.86 mol/m3:
#     pressure = 105989.86691093635 Pa
#     pressure = 1.0598986691093635 bar
