# %% [markdown]
# # Cubic equations of state

# %% [markdown]
# ## Creating the equation of state from already defined objects of mordu

# %%
import mordu 

# select the fluid
NH3 = mordu.fluids.NH3

# select the cp0 object
cp0 = mordu.cp0s.NH3_cp0_NIST
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import mordu
#       3 # select the fluid
#       4 NH3 = mordu.fluids.NH3
#
# File c:\Users\catar\AppData\Local\Programs\Python\Python313\Lib\site-packages\mordu\__init__.py:2
#       1 from .purefluid import PureFluid
# ----> 2 from .storeroom import fluids
#       3 from .storeroom import cp0s
#       4 from .symbols import *
#
# File c:\Users\catar\AppData\Local\Programs\Python\Python313\Lib\site-packages\mordu\storeroom\__init__.py:2
#       1 from ..purefluid import PureFluid
# ----> 2 from ..cp0 import Cp0
#
# File c:\Users\catar\AppData\Local\Programs\Python\Python313\Lib\site-packages\mordu\cp0.py:3
#       1 #03/03/2025
#       2 import sympy as sp
# ----> 3 from symbols import *   #sympy symbols
#       4 from .purefluid import PureFluid
#       6 from .storeroom.fluids import H2, NH3, CH4, N2, CO2, CH3OH , C2H5OH, C2H6, C8H18, C4H9OH, C7H16, H2O
#
# ModuleNotFoundError: No module named 'symbols'
